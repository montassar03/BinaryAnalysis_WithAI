# %% [markdown]
# # Exercise 1 - Exercise and Project Environment

# %% [markdown]
# 1. Make yourself familiar with [Google Colab](https://colab.research.google.com/).
#     * Tutorial: https://colab.research.google.com/notebooks/intro.ipynb
#
# 2. Open a notebook from this repository in Colab using the GitHub integration.
#
# Optional (in particular for project work):
# * Set up a local Python environment using `venv` or `uv` as described in the [`README.md`](../README.md) of this repository.
#
# No submission to Uni2Work required.

# %%
# !git clone https://github.com/scalable-infrastructure/exercise-2026
# Out:
# Cloning into 'exercise-2026'...
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 66 (delta 25), reused 23 (delta 12), pack-reused 20 (from 3)
# Receiving objects: 100% (66/66), 19.96 MiB | 35.85 MiB/s, done.
# Resolving deltas: 100% (25/25), done.

# %%
# %cd exercise-2026
# Out:
# /content/exercise-2026

# %%
# !pip install .
# Out:
# Processing /content/exercise-2026
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 40.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 61.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 52.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 3.6 MB/s eta 0:00:00
# ...
#   Created wheel for scalable-ai-exercises: filename=scalable_ai_exercises-2026.0.0-py3-none-any.whl size=1458 sha256=363cf4a945419e0572ed29138e5f4aa2b314d8c8faca51641eb196fcd67af661
#   Stored in directory: /root/.cache/pip/wheels/d5/97/fa/3942030a3867cf7801c36984279c88915dd1028a7dac51d358
# Successfully built scalable-ai-exercises
# ...
